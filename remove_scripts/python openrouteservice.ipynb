# %% [markdown]
# # OPENROUTESERVICE
#
# API Services Include: **Directions**, **Isochrones**, Time-Distance Matrix, **Geocoding**, **Places Of Interest**, Elevation, Optimization

# %% [markdown]
# # NOTES
# * for more information, visit python package index and search for openrouteservice
# * openrouteservice requires an API key
# * openrouteservice coordinates entered longitude, latitude however folium coordinates entered latitude, longitude

# %% [markdown]
# # IMPORTS

# %%
import openrouteservice as ors
import folium
#import PYTHON_API_KEYS

# %% [markdown]
# # API KEY REQUIRED
# vist https://openrouteservice.org to acquire API key

# %%
# enter your openrouteservice api key here as string
ors_key = '5b3ce3597851110001cf6248aef1603668334dab9cd2bb51fe0518dc'

# performs requests to the ORS API services
# client will be used in all examples
client = ors.Client(key=ors_key)

# %% [markdown]
# # DIRECTIONS
#
# profile argument (string): specifies the mode of transport to use when calculating directions, options: driving-car, driving-hgv, foot-walking, foot-hiking, cycling-regular, cycling-road, cycling-mountain, cycling-electric

# %%
# coordinates from Nashville, TN (-86.781247, 36.163532) to Miami, FL (-80.191850, 25.771645)
# order for coordinates is [lon, lat]


coordinates = [[25.846699816341157, 51.34257027471092], [30.45728813480353, 50.44906817316395]]

# directions
route = client.directions(coordinates=coordinates,
                          profile='driving-car',
                          format='geojson',
                          units='km')

# map
map_directions = folium.Map(location=[33.77, -84.37], zoom_start=5)

# add geojson to map
folium.GeoJson(route, name='route').add_to(map_directions)

# add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_directions)

# display map
map_directions
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b422bd0cfb9f54ae8b34136008a392d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b422bd0cfb9f54ae8b34136008a392d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b422bd0cfb9f54ae8b34136008a392d4 = L.map(
#                 &quot;map_b422bd0cfb9f54ae8b34136008a392d4&quot;,
#                 {
#                     center: [33.77, -84.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_206450abe8e1535e2ccc684876f023e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b422bd0cfb9f54ae8b34136008a392d4);
#
#
#
#         function geo_json_288b331d3ec94dbbf1b519ce7a65fb30_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_288b331d3ec94dbbf1b519ce7a65fb30 = L.geoJson(null, {
#                 onEachFeature: geo_json_288b331d3ec94dbbf1b519ce7a65fb30_onEachFeature,
#
#         });
#
#         function geo_json_288b331d3ec94dbbf1b519ce7a65fb30_add (data) {
#             geo_json_288b331d3ec94dbbf1b519ce7a65fb30
#                 .addData(data)
#                 .addTo(map_b422bd0cfb9f54ae8b34136008a392d4);
#         }
#             geo_json_288b331d3ec94dbbf1b519ce7a65fb30_add({&quot;bbox&quot;: [25.844335, 50.448046, 30.457262, 51.347088], &quot;features&quot;: [{&quot;bbox&quot;: [25.844335, 50.448046, 30.457262, 51.347088], &quot;geometry&quot;: {&quot;coordinates&quot;: [[25.846741, 51.342517], [25.846346, 51.342398], [25.845797, 51.343056], [25.845756, 51.343204], [25.845655, 51.343325], [25.845509, 51.3436], [25.84493, 51.344196], [25.844861, 51.344319], [25.844765, 51.344308], [25.844692, 51.344302], [25.844416, 51.344362], [25.844335, 51.344368], [25.844683, 51.344953], [25.844923, 51.345317], [25.844982, 51.34542], [25.845055, 51.345577], [25.845113, 51.345653], [25.845324, 51.34573], [25.84741, 51.346333], [25.847728, 51.346424], [25.848056, 51.346518], [25.849094, 51.346808], [25.849504, 51.346933],
for index, i in enumerate(route['features'][0]['properties']['segments'][0]['steps']):
    print(index+1, i, '\n')
# Out:
# 0.22650277829100002 miles
# 5.261809765 hours
#
# directions
# 1 {'distance': 0.03, 'duration': 5.5, 'type': 11, 'instruction': 'Head southwest', 'name': '-', 'way_points': [0, 1]}
#
# 2 {'distance': 0.239, 'duration': 43.0, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [1, 7]}
#
# 3 {'distance': 0.038, 'duration': 9.1, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [7, 11]}
#
# 4 {'distance': 0.153, 'duration': 16.6, 'type': 3, 'instruction': 'Turn sharp right onto Паркова вулиця', 'name': 'Паркова вулиця', 'way_points': [11, 16]}
#
# 5 {'distance': 0.226, 'duration': 18.1, 'type': 5, 'instruction': 'Turn slight right', 'name': '-', 'way_points': [16, 20]}
#
# 6 {'distance': 0.152, 'duration': 12.2, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [20, 25]}
#
# 7 {'distance': 0.728, 'duration': 58.4, 'type': 1, 'instruction': 'Turn right onto Тараса Шевченка проспект', 'name': 'Тараса Шевченка проспект', 'way_points': [25, 44]}
#
# 8 {'distance': 0.057, 'duration': 10.3, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [44, 46]}
#
# 9 {'distance': 0.222, 'duration': 33.3, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [46, 53]}
#
# 10 {'distance': 3.028, 'duration': 260.4, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [53, 80]}
#
# 11 {'distance': 3.808, 'duration': 274.2, 'type': 0, 'instruction': 'Turn left onto О-180206', 'name': 'О-180206', 'way_points': [80, 112]}
#
# 12 {'distance': 4.911, 'duration': 353.6, 'type': 0, 'instruction': 'Turn left onto О-180206', 'name': 'О-180206', 'way_points': [112, 157]}
#
# 13 {'distance': 0.139, 'duration': 19.1, 'type': 0, 'instruction': 'Turn left onto О-180207', 'name': 'О-180207', 'way_points': [157, 163]}
#
# 14 {'distance': 1.988, 'duration': 142.1, 'type': 13, 'instruction': 'Keep right onto О-180207', 'name': 'О-180207', 'way_points': [163, 190]}
#
# 15 {'distance': 6.74, 'duration': 404.4, 'type': 1, 'instruction': 'Turn right onto Т-18-08', 'name': 'Т-18-08', 'way_points': [190, 220]}
#
# 16 {'distance': 0.808, 'duration': 48.5, 'type': 0, 'instruction': 'Turn left onto Т-18-08', 'name': 'Т-18-08', 'way_points': [220, 222]}
#
# 17 {'distance': 41.907, 'duration': 1951.2, 'type': 0, 'instruction': 'Turn left onto М-07', 'name': 'М-07', 'way_points': [222, 385]}
#
# 18 {'distance': 0.141, 'duration': 14.4, 'type': 7, 'instruction': 'Enter the roundabout and take the 1st exit onto М-07', 'name': 'М-07', 'exit_number': 1, 'way_points': [385, 394]}
#
# 19 {'distance': 22.653, 'duration': 1046.0, 'type': 6, 'instruction': 'Continue straight onto Варшавська вулиця, М-07', 'name': 'Варшавська вулиця, М-07', 'way_points': [394, 461]}
#
# 20 {'distance': 129.362, 'duration': 6078.7, 'type': 6, 'instruction': 'Continue straight onto М-07', 'name': 'М-07', 'way_points': [461, 786]}
#
# 21 {'distance': 85.142, 'duration': 3948.2, 'type': 6, 'instruction': 'Continue straight onto М-07', 'name': 'М-07', 'way_points': [786, 1074]}
#
# 22 {'distance': 13.097, 'duration': 671.6, 'type': 6, 'instruction': 'Continue straight onto М-07', 'name': 'М-07', 'way_points': [1074, 1147]}
#
# 23 {'distance': 0.114, 'duration': 20.4, 'type': 7, 'instruction': 'Enter the roundabout and take the 2nd exit onto Київська вулиця, М-07', 'name': 'Київська вулиця, М-07', 'exit_number': 2, 'way_points': [1147, 1155]}
#
# 24 {'distance': 24.693, 'duration': 1365.2, 'type': 5, 'instruction': 'Turn slight right onto Київська вулиця, М-07', 'name': 'Київська вулиця, М-07', 'way_points': [1155, 1309]}
#
# 25 {'distance': 3.977, 'duration': 346.8, 'type': 5, 'instruction': 'Turn slight right onto Шевченка вулиця, М-07', 'name': 'Шевченка вулиця, М-07', 'way_points': [1309, 1355]}
#
# 26 {'distance': 0.182, 'duration': 25.8, 'type': 7, 'instruction': 'Enter the roundabout and take the 1st exit onto Свято-Покровська вулиця, М-07', 'name': 'Свято-Покровська вулиця, М-07', 'exit_number': 1, 'way_points': [1355, 1363]}
#
# 27 {'distance': 7.508, 'duration': 457.9, 'type': 6, 'instruction': 'Continue straight onto Свято-Покровська вулиця, М-07', 'name': 'Свято-Покровська вулиця, М-07', 'way_points': [1363, 1435]}
#
# 28 {'distance': 2.133, 'duration': 182.8, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [1435, 1453]}
#
# 29 {'distance': 0.133, 'duration': 26.0, 'type': 0, 'instruction': 'Turn left onto Гостомельська площа', 'name': 'Гостомельська площа', 'way_points': [1453, 1457]}
#
# 30 {'distance': 2.357, 'duration': 198.2, 'type': 6, 'instruction': 'Continue straight onto Стеценка вулиця', 'name': 'Стеценка вулиця', 'way_points': [1457, 1509]}
#
# 31 {'distance': 0.963, 'duration': 101.0, 'type': 7, 'instruction': 'Enter the roundabout and take the 2nd exit onto Стеценка вулиця', 'name': 'Стеценка вулиця', 'exit_number': 2, 'way_points': [1509, 1538]}
#
# 32 {'distance': 2.508, 'duration': 305.7, 'type': 1, 'instruction': 'Turn right onto Данила Щербаківського вулиця', 'name': 'Данила Щербаківського вулиця', 'way_points': [1538, 1610]}
#
# 33 {'distance': 0.187, 'duration': 31.0, 'type': 7, 'instruction': 'Enter the roundabout and take the 2nd exit', 'name': '-', 'exit_number': 2, 'way_points': [1610, 1621]}
#
# 34 {'distance': 0.183, 'duration': 16.5, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [1621, 1624]}
#
# 35 {'distance': 1.074, 'duration': 106.9, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [1624, 1643]}
#
# 36 {'distance': 1.561, 'duration': 136.1, 'type': 6, 'instruction': 'Continue straight onto Перемоги проспект', 'name': 'Перемоги проспект', 'way_points': [1643, 1660]}
#
# 37 {'distance': 0.5, 'duration': 57.4, 'type': 6, 'instruction': 'Continue straight onto Перемоги проспект', 'name': 'Перемоги проспект', 'way_points': [1660, 1666]}
#
# 38 {'distance': 0.532, 'duration': 76.6, 'type': 1, 'instruction': 'Turn right onto Академіка Янгеля вулиця', 'name': 'Академіка Янгеля вулиця', 'way_points': [1666, 1681]}
#
# 39 {'distance': 0.159, 'duration': 28.7, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [1681, 1685]}
#
# 40 {'distance': 0.011, 'duration': 4.0, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [1685, 1686]}
#
# 41 {'distance': 0.045, 'duration': 8.2, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [1686, 1687]}
#
# 42 {'distance': 0.104, 'duration': 18.7, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [1687, 1691]}
#
# 43 {'distance': 0.008, 'duration': 5.5, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [1691, 1692]}
#
# 44 {'distance': 0.018, 'duration': 4.4, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [1692, 1693]}
#
# 45 {'distance': 0.0, 'duration': 0.0, 'type': 10, 'instruction': 'Arrive at your destination, on the right', 'name': '-', 'way_points': [1693, 1693]}

# %% [markdown]
# # ISOCHRONES
# An isochrone map depicts the area accessible from a point within a certain time threshold.
#
# Reachable or accessible areas can be shown graphically by isochrones. Isochrones are imaginary lines passing through all the places that can be reached from a particular origin within a specified travel time.

# %%
# coordinates
coordinates = [[-80.127995, 25.784097]]

# isochrone
isochrone = client.isochrones(locations=coordinates,
                              range_type='time',
                              # 900 seconds, 15 minutes
                              range=[900],
                              attributes=['total_pop'])

# map
map_isochrone = folium.Map(location=[25.784097, -80.127995], tiles='cartodbpositron', zoom_start=12)

# add geojson to map with population
population = isochrone['features'][0]['properties']['total_pop']
folium.GeoJson(isochrone, name='isochrone', tooltip=f'population: {population:,.0f}').add_to(map_isochrone)

# add marker to map
minutes = isochrone['features'][0]['properties']['value']/60
popup_message = f'outline shows areas reachable within {minutes} minutes'
folium.Marker([25.784097, -80.127995], popup=popup_message, tooltip='click').add_to(map_isochrone)

# add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_isochrone)

# display map
map_isochrone
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b92a4333eae5026757a81e5ba7c96331 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b92a4333eae5026757a81e5ba7c96331&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b92a4333eae5026757a81e5ba7c96331 = L.map(
#                 &quot;map_b92a4333eae5026757a81e5ba7c96331&quot;,
#                 {
#                     center: [25.784097, -80.127995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0924265e40f05d06cec16e061904b98e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b92a4333eae5026757a81e5ba7c96331);
#
#
#
#         function geo_json_79dcbbb5d50551fc6a06ed8df2f60e80_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_79dcbbb5d50551fc6a06ed8df2f60e80 = L.geoJson(null, {
#                 onEachFeature: geo_json_79dcbbb5d50551fc6a06ed8df2f60e80_onEachFeature,
#
#         });
#
#         function geo_json_79dcbbb5d50551fc6a06ed8df2f60e80_add (data) {
#             geo_json_79dcbbb5d50551fc6a06ed8df2f60e80
#                 .addData(data)
#                 .addTo(map_b92a4333eae5026757a81e5ba7c96331);
#         }
#             geo_json_79dcbbb5d50551fc6a06ed8df2f60e80_add({&quot;bbox&quot;: [-80.209595, 25.766306, -80.118362, 25.858825], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[
# %% [markdown]
# # PELIAS GEOCODING

# %%
# map
map_geocode = folium.Map(location=[31.7755, -106.4664], tiles='cartodbpositron', zoom_start=13)

# address
address = '4001 E Paisano Dr, El Paso, TX, 79905'

# geocode
geocode = client.pelias_search(text=address, focus_point=list(reversed(map_geocode.location)))

# add marker to map (El Paso Zoo)
for result in geocode['features']:
    folium.Marker(location=list(reversed(result['geometry']['coordinates'])),
                  icon=folium.Icon(icon='building', color='green', prefix='fa'),
                  popup=folium.Popup(result['properties']['name'])).add_to(map_geocode)

# display map
map_geocode
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0435b6949c5ce1dca7d97c645e9a994 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0435b6949c5ce1dca7d97c645e9a994&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e0435b6949c5ce1dca7d97c645e9a994 = L.map(
#                 &quot;map_e0435b6949c5ce1dca7d97c645e9a994&quot;,
#                 {
#                     center: [31.7755, -106.4664],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59573eebf69f86f74ade0d20882d6635 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e0435b6949c5ce1dca7d97c645e9a994);
#
#
#             var marker_10782e3e24a81604957beb66eb553888 = L.marker(
#                 [31.768983, -106.443814],
#                 {}
#             ).addTo(map_e0435b6949c5ce1dca7d97c645e9a994);
#
#
#             var icon_27e2cab07765168b4d2f9699b2b89cf4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_10782e3e24a81604957beb66eb553888.setIcon(icon_27e2cab07765168b4d2f9699b2b89cf4);
#
#
#         var popup_625db877f11b50bde6dcd142e1216ff3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4c2c0639f219dfb6955c2d62ca0984c5 = $(`&lt;div id=&quot;html_4c2c0639f219dfb6955c2d62ca0984c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4001 East Paisano Drive&lt;/div&gt;`)[0];
#             popup_625db877f11b50bde6dcd142e1216ff3.setContent(html_4c2c0639f219dfb6955c2d62ca0984c5);
#
#
#         marker_10782e3e24a81604957beb66eb553888.bindPopup(popup_625db877f11b50bde6dcd142e1216ff3)
#         ;
#
#
#
#
#             var marker_8aebc119df4923b0c0862a668e4e8f9c = L.marker(
#                 [31.768608, -106.444054],
#                 {}
#             ).addTo(map_e0435b6949c5ce1dca7d97c645e9a994);
#
#
#             var icon_0a9e4dd0a79a8ef5f62b4c88e10a0eb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8aebc119df4923b0c0862a668e4e8f9c.setIcon(icon_0a9e4dd0a79a8ef5f62b4c88e10a0eb5);
#
#
#         var popup_2c7ad58ca8a43524c59dc5f4cadde44a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0793b186b0e345acd928cc056d31cfb9 = $(`&lt;div id=&quot;html_0793b186b0e345acd928cc056d31cfb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4001 East Paisano Dr Wb&lt;/div&gt;`)[0];
#             popup_2c7ad58ca8a43524c59dc5f4cadde44a.setContent(html_0793b186b0e345acd928cc056d31cfb9);
#
#
#         marker_8aebc119df4923b0c0862a668e4e8f9c.bindPopup(popup_2c7ad58ca8a43524c59dc5f4cadde44a)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # POIS - PLACES OF INTEREST
# filter_category_ids = https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml

# %%
# coordinates
geojson = {"type": "point", "coordinates": [-106.435073, 31.774464]}
coordinates = [31.774464, -106.435073]

# places of interest
pois = client.places(request='pois',
                     geojson=geojson,
                     # buffer searches (in meters) around specified point
                     buffer=2000,
                     # hospital: 206, restaurant: 570
                     filter_category_ids=[206, 570])

# map
map_pois = folium.Map(location=coordinates, tiles='cartodbpositron', zoom_start=14)

# add center point
folium.Marker(coordinates, icon=folium.Icon(color='red')).add_to(map_pois)

# add search area circle
folium.Circle(radius=2000, location=coordinates, color='green').add_to(map_pois)

# add markers to map
for poi in pois['features']:
    folium.Marker(location=list(reversed(poi['geometry']['coordinates'])),
                  icon=folium.Icon(color='blue'),
                  popup=folium.Popup(poi['properties']['osm_tags']['name'])).add_to(map_pois)

# display map
map_pois
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_539c05227eecb21bfdc637d536ab6785 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_539c05227eecb21bfdc637d536ab6785&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_539c05227eecb21bfdc637d536ab6785 = L.map(
#                 &quot;map_539c05227eecb21bfdc637d536ab6785&quot;,
#                 {
#                     center: [31.774464, -106.435073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_387eda1cd99ff56c24a137c4bdab88e4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_539c05227eecb21bfdc637d536ab6785);
#
#
#             var marker_8ba28efda149500ed2a64c5d6a771124 = L.marker(
#                 [31.774464, -106.435073],
#                 {}
#             ).addTo(map_539c05227eecb21bfdc637d536ab6785);
#
#
#             var icon_f950c8bff2f14b22e7e6facdca15c55c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ba28efda149500ed2a64c5d6a771124.setIcon(icon_f950c8bff2f14b22e7e6facdca15c55c);
#
#
#             var circle_f197d158fbe5b87188d8f12b4830d112 = L.circle(
#                 [31.774464, -106.435073],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_539c05227eecb21bfdc637d536ab6785);
#
#
#             var marker_12ba37b97612235d4d9ddc60e89caa5c = L.marker(
#                 [31.779435, -106.449883],
#                 {}
#             ).addTo(map_539c05227eecb21bfdc637d536ab6785);
#
#
#             var icon_8aad46f9f8b85bf8ec0ea2594344f2dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_12ba37b97612235d4d9ddc60e89caa5c.setIcon(icon_8aad46f9f8b85bf8ec0ea2594344f2dc);
#
#
#         var popup_9a063d12cb9828742628a78b9f009381 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1467b169f41da2bfddeb21007063366d = $(`&lt;div id=&quot;html_1467b169f41da2bfddeb21007063366d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L &amp; J Cafe&lt;/div&gt;`)[0];
#             popup_9a063d12cb9828742628a78b9f009381.setContent(html_1467b169f41da2bfddeb21007063366d);
#
#
#         marker_12ba37b97612235d4d9ddc60e89caa5c.bindPopup(popup_9a063d12cb9828742628a78b9f009381)
#         ;
#
#
#
#
#             var marker_a42bb8b5fbe0475d92aad66e98a367e5 = L.marker(
#                 [31.771707, -106.434647],
#                 {}
#             ).addTo(map_539c05227eecb21bfdc637d536ab6785);
#
#
#             var icon_354b6f4c51fb02a48ea80722a713dc5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a42bb8b5fbe0475d92aad66e98a367e5.setIcon(icon_354b6f4c51fb02a48ea80722a713dc5f);
#
#
#         var popup_bda275d3c91b55d27cf625b9430297c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_863315579a8861807323334a6003382a = $(`&lt;div id=&quot;html_863315579a8861807323334a6003382a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University Medical Center&lt;/div&gt;`)[0];
#             popup_bda275d3c91b55d27cf625b9430297c6.setContent(html_863315579a8861807323334a6003382a);
#
#
#         marker_a42bb8b5fbe0475d92aad66e98a367e5.bindPopup(popup_bda275d3c91b55d27cf625b9430297c6)
#         ;
#
#
#
#
#             var marker_55570b1430eadf46e87dc215e30f274b = L.marker(
#                 [31.772, -106.43622],
#                 {}
#             ).addTo(map_539c05227eecb21bfdc637d536ab6785);
#
#
#             var icon_cbaafa382d3232337c195834b411652a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &q
